# %% [markdown]
# #Q1. Comments in Python

# %%
# Single-line comment
print("Hello")

"""
Multi-line comment
"""
# Out:
# Hello
# '\nMulti-line comment\n'

# %%
# Q2. What are variables in Python? How do you declare and assign values?

x = 10
name = "Shubham"
price = 99.5

print(x, name, price)
# Out:
# 10 Shubham 99.5

# %%
# Q3. How do you convert one data type to another in Python?

a = "10"
b = int(a)

c = 5
d = float(c)

e = 3.5
f = str(e)

print(b, d, f)
# Out:
# 10 5.0 3.5

# %%
# Q4. How do you write and execute a Python script from command line?

# Run in terminal:
# python script.py

# %%
# Q5. Slice list to get [2, 3]

my_list = [1, 2, 3, 4, 5]
sub_list = my_list[1:3]

print(sub_list)
# Out:
# [2, 3]

# %%
# Q6. What is a complex number and how is it represented?

z = 2 + 3j

print(z)
print(type(z))
# Out:
# (2+3j)
# <class 'complex'>

# %%
# Q7. Declare variable age = 25

age = 25
print(age)
# Out:
# 25

# %%
# Q8. Declare price = 9.99 and check data type

price = 9.99

print(price)
print(type(price))
# Out:
# 9.99
# <class 'float'>

# %%
# Q9. Create variable name and print it

name = "Shubham Khatri"

print(name)
# Out:
# Shubham Khatri

# %%
# Q10. Extract "World" from string

text = "Hello, World!"

print(text[7:12])
# Out:
# World

# %%
# Q11. Boolean variable is_student

is_student = True

print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>
